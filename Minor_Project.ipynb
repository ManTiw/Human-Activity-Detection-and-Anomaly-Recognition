# %%
pip install tensorflow opencv-python
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.10/dist-packages (2.15.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.25.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow) (24.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (0.37.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (1.63.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %%
pip install PyDrive
# Out:
# Requirement already satisfied: PyDrive in /usr/local/lib/python3.10/dist-packages (1.3.1)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.10/dist-packages (from PyDrive) (2.84.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from PyDrive) (4.1.3)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.10/dist-packages (from PyDrive) (6.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.22.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (2.27.0)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (0.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (2.11.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from google-api-python-client>=1.2->PyDrive) (4.1.1)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.6.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=4.0.0->PyDrive) (0.4.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=4.0.0->PyDrive) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client>=4.0.0->PyDrive) (1.16.0)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->PyDrive) (1.63.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->PyDrive) (3.20.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /usr/local/lib/python3.10/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2.31.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.2->PyDrive) (5.3.3)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client>=1.2->PyDrive) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->PyDrive) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->PyDrive) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->PyDrive) (2024.2.2)

# %%
from google.colab import drive
drive.mount('/content/drive')
#, force_remount=True
# Out:
# Mounted at /content/drive

# %%
#file_path = '/content/drive/MyDrive/Minor__Data/minor.zip'
# !cp "/content/drive/MyDrive/Minor__Data/minor.zip" "/content/"

# %%
# !unzip minor
# Out:
# Archive:  minor.zip
#    creating: minor/boxing/
#   inflating: minor/boxing/person01_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person01_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person01_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person01_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person02_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person02_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person02_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person02_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person03_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person03_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person03_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person03_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person04_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person04_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person04_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person04_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person05_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person05_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person05_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person05_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person06_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person06_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person06_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person06_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person07_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person07_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person07_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person07_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person08_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person08_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person08_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person08_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person09_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person09_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person09_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person09_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person10_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person10_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person10_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person10_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person11_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person11_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person11_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person11_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person12_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person12_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person12_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person12_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person13_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person13_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person13_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person13_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person14_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person14_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person14_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person14_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person15_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person15_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person15_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person15_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person16_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person16_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person16_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person16_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person17_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person17_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person17_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person17_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person18_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person18_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person18_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person18_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person19_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person19_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person19_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person19_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person20_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person20_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person20_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person20_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person21_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person21_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person21_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person21_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person22_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person22_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person22_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person22_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person23_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person23_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person23_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person23_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person24_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person24_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person24_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person24_boxing_d4_uncomp.avi
#   inflating: minor/boxing/person25_boxing_d1_uncomp.avi
#   inflating: minor/boxing/person25_boxing_d2_uncomp.avi
#   inflating: minor/boxing/person25_boxing_d3_uncomp.avi
#   inflating: minor/boxing/person25_boxing_d4_uncomp.avi
#    creating: minor/fights/
#   inflating: minor/fights/newfi1.avi
#   inflating: minor/fights/newfi10.avi
#   inflating: minor/fights/newfi100.avi
#   inflating: minor/fights/newfi11.avi
#   inflating: minor/fights/newfi12.avi
#   inflating: minor/fights/newfi13.avi
#   inflating: minor/fights/newfi14.avi
#   inflating: minor/fights/newfi15.avi
#   inflating: minor/fights/newfi16.avi
#   inflating: minor/fights/newfi17.avi
#   inflating: minor/fights/newfi18.avi
#   inflating: minor/fights/newfi19.avi
#   inflating: minor/fights/newfi2.avi
#   inflating: minor/fights/newfi20.avi
#   inflating: minor/fights/newfi21.avi
#   inflating: minor/fights/newfi22.avi
#   inflating: minor/fights/newfi23.avi
#   inflating: minor/fights/newfi24.avi
#   inflating: minor/fights/newfi25.avi
#   inflating: minor/fights/newfi26.avi
#   inflating: minor/fights/newfi27.avi
#   inflating: minor/fights/newfi28.avi
#   inflating: minor/fights/newfi29.avi
#   inflating: minor/fights/newfi3.avi
#   inflating: minor/fights/newfi30.avi
#   inflating: minor/fights/newfi31.avi
#   inflating: minor/fights/newfi32.avi
#   inflating: minor/fights/newfi33.avi
#   inflating: minor/fights/newfi34.avi
#   inflating: minor/fights/newfi35.avi
#   inflating: minor/fights/newfi36.avi
#   inflating: minor/fights/newfi37.avi
#   inflating: minor/fights/newfi38.avi
#   inflating: minor/fights/newfi39.avi
#   inflating: minor/fights/newfi4.avi
#   inflating: minor/fights/newfi40.avi
#   inflating: minor/fights/newfi41.avi
#   inflating: minor/fights/newfi42.avi
#   inflating: minor/fights/newfi43.avi
#   inflating: minor/fights/newfi44.avi
#   inflating: minor/fights/newfi45.avi
#   inflating: minor/fights/newfi46.avi
#   inflating: minor/fights/newfi47.avi
#   inflating: minor/fights/newfi48.avi
#   inflating: minor/fights/newfi49.avi
#   inflating: minor/fights/newfi5.avi
#   inflating: minor/fights/newfi50.avi
#   inflating: minor/fights/newfi51.avi
#   inflating: minor/fights/newfi52.avi
#   inflating: minor/fights/newfi53.avi
#   inflating: minor/fights/newfi54.avi
#   inflating: minor/fights/newfi55.avi
#   inflating: minor/fights/newfi56.avi
#   inflating: minor/fights/newfi57.avi
#   inflating: minor/fights/newfi58.avi
#   inflating: minor/fights/newfi59.avi
#   inflating: minor/fights/newfi6.avi
#   inflating: minor/fights/newfi60.avi
#   inflating: minor/fights/newfi61.avi
#   inflating: minor/fights/newfi62.avi
#   inflating: minor/fights/newfi63.avi
#   inflating: minor/fights/newfi64.avi
#   inflating: minor/fights/newfi65.avi
#   inflating: minor/fights/newfi66.avi
#   inflating: minor/fights/newfi67.avi
#   inflating: minor/fights/newfi68.avi
#   inflating: minor/fights/newfi69.avi
#   inflating: minor/fights/newfi7.avi
#   inflating: minor/fights/newfi70.avi
#   inflating: minor/fights/newfi71.avi
#   inflating: minor/fights/newfi72.avi
#   inflating: minor/fights/newfi73.avi
#   inflating: minor/fights/newfi74avi.avi
#   inflating: minor/fights/newfi75.avi
#   inflating: minor/fights/newfi76.avi
#   inflating: minor/fights/newfi77.avi
#   inflating: minor/fights/newfi78.avi
#   inflating: minor/fights/newfi79.avi
#   inflating: minor/fights/newfi8.avi
#   inflating: minor/fights/newfi80.avi
#   inflating: minor/fights/newfi81.avi
#   inflating: minor/fights/newfi82.avi
#   inflating: minor/fights/newfi83.avi
#   inflating: minor/fights/newfi84.avi
#   inflating: minor/fights/newfi85.avi
#   inflating: minor/fights/newfi86.avi
#   inflating: minor/fights/newfi87.avi
#   inflating: minor/fights/newfi88.avi
#   inflating: minor/fights/newfi89.avi
#   inflating: minor/fights/newfi9.avi
#   inflating: minor/fights/newfi90.avi
#   inflating: minor/fights/newfi91.avi
#   inflating: minor/fights/newfi92.avi
#   inflating: minor/fights/newfi93.avi
#   inflating: minor/fights/newfi94.avi
#   inflating: minor/fights/newfi95.avi
#   inflating: minor/fights/newfi96.avi
#   inflating: minor/fights/newfi97.avi
#   inflating: minor/fights/newfi98.avi
#   inflating: minor/fights/newfi99.avi
#    creating: minor/handclapping/
#   inflating: minor/handclapping/person01_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person01_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person01_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/person01_handclapping_d4_uncomp.avi
#   inflating: minor/handclapping/person02_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person02_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person02_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/person02_handclapping_d4_uncomp.avi
#   inflating: minor/handclapping/person03_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person03_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person03_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/person03_handclapping_d4_uncomp.avi
#   inflating: minor/handclapping/person04_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person04_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person04_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/person04_handclapping_d4_uncomp.avi
#   inflating: minor/handclapping/person05_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person05_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person05_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/person05_handclapping_d4_uncomp.avi
#   inflating: minor/handclapping/person06_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person06_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person06_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/person06_handclapping_d4_uncomp.avi
#   inflating: minor/handclapping/person07_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person07_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person07_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/person07_handclapping_d4_uncomp.avi
#   inflating: minor/handclapping/person08_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person08_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person08_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/person08_handclapping_d4_uncomp.avi
#   inflating: minor/handclapping/person09_handclapping_d1_uncomp.avi
#   inflating: minor/handclapping/person09_handclapping_d2_uncomp.avi
#   inflating: minor/handclapping/person09_handclapping_d3_uncomp.avi
#   inflating: minor/handclapping/
jogging_d3_uncomp.avi
#   inflating: minor/jogging/person24_jogging_d4_uncomp.avi
#   inflating: minor/jogging/person25_jogging_d1_uncomp.avi
#   inflating: minor/jogging/person25_jogging_d2_uncomp.avi
#   inflating: minor/jogging/person25_jogging_d3_uncomp.avi
#   inflating: minor/jogging/person25_jogging_d4_uncomp.avi
#    creating: minor/noFights/
#   inflating: minor/noFights/1.mpg
#   inflating: minor/noFights/10.mpg
#   inflating: minor/noFights/100.mpg
#   inflating: minor/noFights/11.mpg
#   inflating: minor/noFights/12 (1).mpg
#   inflating: minor/noFights/13.mpg
#   inflating: minor/noFights/14.mpg
#   inflating: minor/noFights/15.mpg
#   inflating: minor/noFights/16.mpg
#   inflating: minor/noFights/17.mpg
#   inflating: minor/noFights/18.mpg
#   inflating: minor/noFights/19.mpg
#   inflating: minor/noFights/2.mpg
#   inflating: minor/noFights/20 (1).mpg
#   inflating: minor/noFights/21.mpg
#   inflating: minor/noFights/22.mpg
#   inflating: minor/noFights/23.mpg
#   inflating: minor/noFights/24.mpg
#   inflating: minor/noFights/25.mpg
#   inflating: minor/noFights/26 (1).mpg
#   inflating: minor/noFights/27.mpg
#   inflating: minor/noFights/28.mpg
#   inflating: minor/noFights/29.mpg
#   inflating: minor/noFights/3.mpg
#   inflating: minor/noFights/30.mpg
#   inflating: minor/noFights/31.mpg
#   inflating: minor/noFights/32.mpg
#   inflating: minor/noFights/33 (1).mpg
#   inflating: minor/noFights/33.mpg
#   inflating: minor/noFights/34.mpg
#   inflating: minor/noFights/35.mpg
#   inflating: minor/noFights/36.mpg
#   inflating: minor/noFights/37.mpg
#   inflating: minor/noFights/38.mpg
#   inflating: minor/noFights/39.mpg
#   inflating: minor/noFights/4 (1).mpg
#   inflating: minor/noFights/40.mpg
#   inflating: minor/noFights/41 (1).mpg
#   inflating: minor/noFights/42 (1).mpg
#   inflating: minor/noFights/43 (1).mpg
#   inflating: minor/noFights/44.mpg
#   inflating: minor/noFights/45.mpg
#   inflating: minor/noFights/46.mpg
#   inflating: minor/noFights/47.mpg
#   inflating: minor/noFights/48.mpg
#   inflating: minor/noFights/49.mpg
#   inflating: minor/noFights/5.mpg
#   inflating: minor/noFights/50.mpg
#   inflating: minor/noFights/51.mpg
#   inflating: minor/noFights/52.mpg
#   inflating: minor/noFights/53.mpg
#   inflating: minor/noFights/54.mpg
#   inflating: minor/noFights/55.mpg
#   inflating: minor/noFights/56.mpg
#   inflating: minor/noFights/57.mpg
#   inflating: minor/noFights/58.mpg
#   inflating: minor/noFights/59.mpg
#   inflating: minor/noFights/6.mpg
#   inflating: minor/noFights/60.mpg
#   inflating: minor/noFights/61.mpg
#   inflating: minor/noFights/62.mpg
#   inflating: minor/noFights/63.mpg
#   inflating: minor/noFights/64.mpg
#   inflating: minor/noFights/65.mpg
#   inflating: minor/noFights/66.mpg
#   inflating: minor/noFights/67 (1).mpg
#   inflating: minor/noFights/68.mpg
#   inflating: minor/noFights/69.mpg
#   inflating: minor/noFights/7.mpg
#   inflating: minor/noFights/70.mpg
#   inflating: minor/noFights/71avi.mpg
#   inflating: minor/noFights/72.mpg
#   inflating: minor/noFights/73.mpg
#   inflating: minor/noFights/74.mpg
#   inflating: minor/noFights/75.mpg
#   inflating: minor/noFights/76.mpg
#   inflating: minor/noFights/77.mpg
#   inflating: minor/noFights/78.mpg
#   inflating: minor/noFights/79.mpg
#   inflating: minor/walking/person13_walking_d2_uncomp.avi
#   inflating: minor/walking/person13_walking_d3_uncomp.avi
#   inflating: minor/walking/person13_walking_d4_uncomp.avi
#   inflating: minor/walking/person14_walking_d1_uncomp.avi
#   inflating: minor/walking/person14_walking_d2_uncomp.avi
#   inflating: minor/walking/person14_walking_d3_uncomp.avi
#   inflating: minor/walking/person14_walking_d4_uncomp.avi
#   inflating: minor/walking/person15_walking_d1_uncomp.avi
#   inflating: minor/walking/person15_walking_d2_uncomp.avi
#   inflating: minor/walking/person15_walking_d3_uncomp.avi
#   inflating: minor/walking/person15_walking_d4_uncomp.avi
#   inflating: minor/walking/person16_walking_d1_uncomp.avi
#   inflating: minor/walking/person16_walking_d2_uncomp.avi
#   inflating: minor/walking/person16_walking_d3_uncomp.avi
#   inflating: minor/walking/person16_walking_d4_uncomp.avi
#   inflating: minor/walking/person17_walking_d1_uncomp.avi
#   inflating: minor/walking/person17_walking_d2_uncomp.avi
#   inflating: minor/walking/person17_walking_d3_uncomp.avi
#   inflating: minor/walking/person17_walking_d4_uncomp.avi
#   inflating: minor/walking/person18_walking_d1_uncomp.avi
#   inflating: minor/walking/person18_walking_d2_uncomp.avi
#   inflating: minor/walking/person18_walking_d3_uncomp.avi
#   inflating: minor/walking/person18_walking_d4_uncomp.avi
#   inflating: minor/walking/person19_walking_d1_uncomp.avi
#   inflating: minor/walking/person19_walking_d2_uncomp.avi
#   inflating: minor/walking/person19_walking_d3_uncomp.avi
#   inflating: minor/walking/person19_walking_d4_uncomp.avi
#   inflating: minor/walking/person20_walking_d1_uncomp.avi
#   inflating: minor/walking/person20_walking_d2_uncomp.avi
#   inflating: minor/walking/person20_walking_d3_uncomp.avi
#   inflating: minor/walking/person20_walking_d4_uncomp.avi
#   inflating: minor/walking/person21_walking_d1_uncomp.avi
#   inflating: minor/walking/person21_walking_d2_uncomp.avi
#   inflating: minor/walking/person21_walking_d3_uncomp.avi
#   inflating: minor/walking/person21_walking_d4_uncomp.avi
#   inflating: minor/walking/person22_walking_d1_uncomp.avi
#   inflating: minor/walking/person22_walking_d2_uncomp.avi
#   inflating: minor/walking/person22_walking_d3_uncomp.avi
#   inflating: minor/walking/person22_walking_d4_uncomp.avi
#   inflating: minor/walking/person23_walking_d1_uncomp.avi
#   inflating: minor/walking/person23_walking_d2_uncomp.avi
#   inflating: minor/walking/person23_walking_d3_uncomp.avi
#   inflating: minor/walking/person23_walking_d4_uncomp.avi
#   inflating: minor/walking/person24_walking_d1_uncomp.avi
#   inflating: minor/walking/person24_walking_d2_uncomp.avi
#   inflating: minor/walking/person24_walking_d3_uncomp.avi
#   inflating: minor/walking/person24_walking_d4_uncomp.avi
#   inflating: minor/walking/person25_walking_d1_uncomp.avi
#   inflating: minor/walking/person25_walking_d2_uncomp.avi
#   inflating: minor/walking/person25_walking_d3_uncomp.avi
#   inflating: minor/walking/person25_walking_d4_uncomp.avi

# %%
# !pip install pafy youtube-dl moviepy
# Out:
# Collecting pafy
#   Downloading pafy-0.5.5-py2.py3-none-any.whl (35 kB)
# Collecting youtube-dl
#   Downloading youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 40.5 MB/s eta 0:00:00
# Requirement already satisfied: moviepy in /usr/local/lib/python3.10/dist-packages (1.0.3)
# Requirement already satisfied: decorator<5.0,>=4.0.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.4.2)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /usr/local/lib/python3.10/dist-packages (from moviepy) (4.66.4)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.0)
# Requirement already satisfied: proglog<=1.0.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.1.10)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from moviepy) (1.25.2)
# Requirement already satisfied: imageio<3.0,>=2.5 in /usr/local/lib/python3.10/dist-packages (from moviepy) (2.31.6)
# Requirement already satisfied: imageio-ffmpeg>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from moviepy) (0.4.9)
# Requirement already satisfied: pillow<10.1.0,>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio<3.0,>=2.5->moviepy) (9.4.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio-ffmpeg>=0.2.0->moviepy) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0,>=2.8.1->moviepy) (2024.2.2)
# Installing collected packages: youtube-dl, pafy
# Successfully installed pafy-0.5.5 youtube-dl-2021.12.17

# %%
import os
import cv2
import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model

# %%
seed_constant = 5
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %%
# !ls
# Out:
# drive  minor  minor.zip  sample_data

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (20, 20))

# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('minor')

# Generate a list of 20 random values. The values will be between 0-50,
# where 50 is the total number of class in the dataset.
# random_range = random.sample(range(len(all_classes_names)), len(all_classes_names))

# Iterating through all the generated random values.
for counter, random_index in enumerate(range(len(all_classes_names)), 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]

    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'minor/{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'minor/{selected_class_Name}/{selected_video_file_name}')
    video_reader.set(1, 25)

    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    bgr_frame = cv2.resize(bgr_frame ,(224,224))
    # Release the VideoCapture object.
    video_reader.release()

    # Convert the frame from BGR into RGB format.
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 200, 255), 2)

    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 30

# Specify the directory containing the UCF50 dataset.
DATASET_DIR = "minor"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ["walking", "fights", "running"]

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''

    # Declare a list to store video frames.
    frames_list = []

    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video.
        success, frame = video_reader.read()

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255

        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)

    # Release the VideoCapture object.
    video_reader.release()

    # Return the frames list.
    return frames_list

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []

    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):

        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')

        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))

        # Iterate through all the files present in the files list.
        for file_name in files_list:

            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)

    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: walking
# Extracting Data of Class: fights
# Extracting Data of Class: running

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels, test_size = 0.25, shuffle = True, random_state = seed_constant)
features = None
labels = None

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################

    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu'), input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))

    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))

    model.add(TimeDistributed(Conv2D(128, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Conv2D(256, (2, 2), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))

    model.add(TimeDistributed(Flatten()))

    model.add(LSTM(32))

    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()

    # Return the constructed LRCN model.
    return model

# %%
model = create_LRCN_model()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDist  (None, 30, 64, 64, 32)    896
#  ributed)
#
#  time_distributed_1 (TimeDi  (None, 30, 16, 16, 32)    0
#  stributed)
#
#  time_distributed_2 (TimeDi  (None, 30, 16, 16, 64)    18496
#  stributed)
#
#  time_distributed_3 (TimeDi  (None, 30, 4, 4, 64)      0
#  stributed)
#
#  time_distributed_4 (TimeDi  (None, 30, 4, 4, 128)     73856
#  stributed)
#
#  time_distributed_5 (TimeDi  (None, 30, 2, 2, 128)     0
#  stributed)
#
#  time_distributed_6 (TimeDi  (None, 30, 2, 2, 256)     131328
#  stributed)
#
#  time_distributed_7 (TimeDi  (None, 30, 1, 1, 256)     0
#  stributed)
#
#  time_distributed_8 (TimeDi  (None, 30, 256)           0
#  stributed)
#
#  lstm (LSTM)                 (None, 32)                36992
#
#  dense (Dense)               (None, 3)                 99
#
# =================================================================
# Total params: 261667 (1022.14 KB)
# Trainable params: 261667 (1022.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#class diagram

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'accuracy', patience = 10, mode = 'max', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics to the model.
model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
model_training_history = model.fit(x = features_train, y = labels_train, epochs = 70, batch_size = 4 , shuffle = True, validation_split = 0.25, callbacks = [early_stopping_callback])
# Out:
# Epoch 1/70
# 42/42 [==============================] - 27s 536ms/step - loss: 0.7531 - accuracy: 0.5833 - val_loss: 0.4312 - val_accuracy: 0.7193
# Epoch 2/70
# 42/42 [==============================] - 27s 643ms/step - loss: 0.5878 - accuracy: 0.5952 - val_loss: 0.4807 - val_accuracy: 0.6842
# Epoch 3/70
# 42/42 [==============================] - 21s 513ms/step - loss: 0.5165 - accuracy: 0.6667 - val_loss: 0.4333 - val_accuracy: 0.6842
# Epoch 4/70
# 42/42 [==============================] - 22s 516ms/step - loss: 0.4729 - accuracy: 0.6190 - val_loss: 0.4302 - val_accuracy: 0.6842
# Epoch 5/70
# 42/42 [==============================] - 23s 534ms/step - loss: 0.4718 - accuracy: 0.6964 - val_loss: 0.4293 - val_accuracy: 0.6842
# Epoch 6/70
# 42/42 [==============================] - 21s 511ms/step - loss: 0.4761 - accuracy: 0.6607 - val_loss: 0.4184 - val_accuracy: 0.7193
# Epoch 7/70
# 42/42 [==============================] - 22s 518ms/step - loss: 0.4659 - accuracy: 0.7143 - val_loss: 0.4102 - val_accuracy: 0.7018
# Epoch 8/70
# 42/42 [==============================] - 25s 589ms/step - loss: 0.4697 - accuracy: 0.6905 - val_loss: 0.4004 - val_accuracy: 0.8947
# Epoch 9/70
# 42/42 [==============================] - 21s 510ms/step - loss: 0.4643 - accuracy: 0.6845 - val_loss: 0.4397 - val_accuracy: 0.6842
# Epoch 10/70
# 42/42 [==============================] - 23s 539ms/step - loss: 0.4726 - accuracy: 0.6667 - val_loss: 0.4266 - val_accuracy: 0.7193
# Epoch 11/70
# 42/42 [==============================] - 21s 503ms/step - loss: 0.4647 - accuracy: 0.6905 - val_loss: 0.4237 - val_accuracy: 0.6842
# Epoch 12/70
# 42/42 [==============================] - 24s 574ms/step - loss: 0.4686 - accuracy: 0.7024 - val_loss: 0.4292 - val_accuracy: 0.7193
# Epoch 13/70
# 42/42 [==============================] - 21s 510ms/step - loss: 0.4683 - accuracy: 0.6786 - val_loss: 0.3653 - val_accuracy: 0.8421
# Epoch 14/70
# 42/42 [==============================] - 24s 563ms/step - loss: 0.2180 - accuracy: 0.9048 - val_loss: 0.1707 - val_accuracy: 0.9298
# Epoch 34/70
# 42/42 [==============================] - 21s 494ms/step - loss: 0.1938 - accuracy: 0.8929 - val_loss: 0.1429 - val_accuracy: 0.9649
# Epoch 35/70
# 42/42 [==============================] - 21s 512ms/step - loss: 0.1773 - accuracy: 0.8988 - val_loss: 0.1794 - val_accuracy: 0.9298
# Epoch 36/70
# 42/42 [==============================] - 23s 554ms/step - loss: 0.1411 - accuracy: 0.9524 - val_loss: 0.2125 - val_accuracy: 0.9474
# Epoch 37/70
# 42/42 [==============================] - 21s 510ms/step - loss: 0.1213 - accuracy: 0.9583 - val_loss: 0.1732 - val_accuracy: 0.9474
# Epoch 38/70
# 42/42 [==============================] - 23s 556ms/step - loss: 0.1356 - accuracy: 0.9524 - val_loss: 0.2654 - val_accuracy: 0.9298
# Epoch 39/70
# 42/42 [==============================] - 22s 515ms/step - loss: 0.1263 - accuracy: 0.9643 - val_loss: 0.1840 - val_accuracy: 0.9298
# Epoch 40/70
# 42/42 [==============================] - 22s 524ms/step - loss: 0.1011 - accuracy: 0.9524 - val_loss: 0.2749 - val_accuracy: 0.9123
# Epoch 41/70
# 42/42 [==============================] - 22s 527ms/step - loss: 0.0746 - accuracy: 0.9762 - val_loss: 0.1809 - val_accuracy: 0.9123
# Epoch 42/70
# 42/42 [==============================] - 24s 567ms/step - loss: 0.0831 - accuracy: 0.9583 - val_loss: 0.2118 - val_accuracy: 0.8772
# Epoch 43/70
# 42/42 [==============================] - 25s 594ms/step - loss: 0.0900 - accuracy: 0.9583 - val_loss: 0.2529 - val_accuracy: 0.9123
# Epoch 44/70
# 42/42 [==============================] - 21s 491ms/step - loss: 0.0402 - accuracy: 1.0000 - val_loss: 0.1803 - val_accuracy: 0.9298
# Epoch 45/70
# 42/42 [==============================] - 24s 578ms/step - loss: 0.0359 - accuracy: 1.0000 - val_loss: 0.2849 - val_accuracy: 0.8947
# Epoch 46/70
# 42/42 [==============================] - 21s 511ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.2406 - val_accuracy: 0.9123
# Epoch 47/70
# 42/42 [==============================] - 21s 509ms/step - loss: 0.0175 - accuracy: 1.0000 - val_loss: 0.3231 - val_accuracy: 0.8772
# Epoch 48/70
# 42/42 [==============================] - 23s 552ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.2422 - val_accuracy: 0.9474
# Epoch 49/70
# 42/42 [==============================] - 21s 513ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9298
# Epoch 50/70
# 42/42 [==============================] - 25s 590ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.2403 - val_accuracy: 0.9474
# Epoch 51/70
# 42/42 [==============================] - 21s 496ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 0.2518 - val_accuracy: 0.9474
# Epoch 52/70
# 42/42 [==============================] - 21s 513ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.2543 - val_accuracy: 0.9298
# Epoch 53/70
# 42/42 [==============================] - 22s 529ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.2626 - val_accuracy: 0.9298
# Epoch 54/70
# 42/42 [==============================] - 21s 510ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.2627 - val_accuracy: 0.9298

# %%
# Save your Model.
model.save("Minor_Project_LRCN_Model.h5")
# Out:
# WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''

    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]

    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %%
plot_metric(model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
plot_metric(model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %%
# Calculate Accuracy On Test Dataset
acc = 0
for i in range(len(features_test)):
  predicted_label = np.argmax(model.predict(np.expand_dims(features_test[i],axis =0))[0])
  actual_label = np.argmax(labels_test[i])
  if predicted_label == actual_label:
      acc += 1
acc = (acc * 100)/len(labels_test)
print("Accuracy =",acc)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 92ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 86ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 91ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 52ms/step
# Accuracy = 84.0

# %%
#file_path = '/content/drive/MyDrive/Minor__Data/minor.zip'
# !cp "/content/drive/MyDrive/Minor_Project_LRCN_Model.h5" "/content/"

# %%
from tensorflow.keras.models import load_model
import cv2
import numpy as np
import pandas as pd
from collections import deque
from moviepy.editor import *

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 30

# Specify the directory containing the UCF50 dataset.
DATASET_DIR = "minor"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ["walking", "fight", "running"]

# %%
model = load_model('Minor_Project_LRCN_Model.h5')

# %%
def predict_single_action(video_file_path, SEQUENCE_LENGTH):
    '''
    This function will perform single action recognition prediction on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    '''

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv2.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Declare a list to store video frames we will extract.
    frames_list = []

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Get the number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH),1)

    # Iterating the number of times equal to the fixed length of sequence.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Read a frame.
        success, frame = video_reader.read()

        # Check if frame is not read properly then break the loop.
        if not success:
            break

        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
        normalized_frame = resized_frame / 255

        # Appending the pre-processed frame into the frames list
        frames_list.append(normalized_frame)

    # Passing the  pre-processed frames to the model and get the predicted probabilities.
    predicted_labels_probabilities = model.predict(np.expand_dims(frames_list, axis = 0))[0]

    # Get the index of class with highest probability.
    predicted_label = np.argmax(predicted_labels_probabilities)

    # Get the class name using the retrieved index.
    predicted_class_name = CLASSES_LIST[predicted_label]

    # Display the predicted action along with the prediction confidence.
    print(f'Action Predicted: {predicted_class_name}\nConfidence: {predicted_labels_probabilities[predicted_label]}')

    # Release the VideoCapture object.
    video_reader.release()

# %%
predict_single_action("/content/minor/fights/newfi1.avi",SEQUENCE_LENGTH)
# Out:
# 1/1 [==============================] - 1s 733ms/step
# Action Predicted: fight
# Confidence: 0.9994224309921265

# %%
predict_single_action("/content/minor/running/person01_running_d1_uncomp.avi",SEQUENCE_LENGTH)
# Out:
# 1/1 [==============================] - 0s 51ms/step
# Action Predicted: running
# Confidence: 0.9962002635002136

# %%
predict_single_action("/content/minor/walking/person01_walking_d1_uncomp.avi",SEQUENCE_LENGTH)
# Out:
# 1/1 [==============================] - 0s 59ms/step
# Action Predicted: walking
# Confidence: 0.9910353422164917

# %%
def predict_on_video(video_file_path, output_file_path, SEQUENCE_LENGTH):
    '''
    This function will perform action recognition on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    output_file_path: The path where the ouput video with the predicted action being performed overlayed will be stored.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    '''

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv2.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Initialize the VideoWriter Object to store the output video in the disk.
    video_writer = cv2.VideoWriter(output_file_path, cv2.VideoWriter_fourcc(*'DIVX'),
                                   video_reader.get(cv2.CAP_PROP_FPS), (original_video_width, original_video_height))

    # Declare a queue to store video frames.
    frames_queue = deque(maxlen = SEQUENCE_LENGTH)

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Iterate until the video is accessed successfully.
    while video_reader.isOpened():

        # Read the frame.
        ok, frame = video_reader.read()

        # Check if frame is not read properly then break the loop.
        if not ok:
            break

        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
        normalized_frame = resized_frame / 255

        # Appending the pre-processed frame into the frames list.
        frames_queue.append(normalized_frame)

        # Check if the number of frames in the queue are equal to the fixed sequence length.
        if len(frames_queue) == SEQUENCE_LENGTH:

            # Pass the normalized frames to the model and get the predicted probabilities.
            predicted_labels_probabilities = model.predict(np.expand_dims(frames_queue, axis = 0))[0]

            # Get the index of class with highest probability.
            predicted_label = np.argmax(predicted_labels_probabilities)

            # Get the class name using the retrieved index.
            predicted_class_name = CLASSES_LIST[predicted_label]

        # Write predicted class name on top of the frame.
        cv2.putText(frame, predicted_class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Write The frame into the disk using the VideoWriter Object.
        video_writer.write(frame)

    # Release the VideoCapture and VideoWriter objects.
    video_reader.release()
    video_writer.release()

# %%
# %%time
predict_on_video("/content/minor/jogging/person02_jogging_d1_uncomp.avi","Human-Activity-Prediction.avi",SEQUENCE_LENGTH)
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 89ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 70ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 72ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 74ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 76ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 88ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 78ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 73ms/step
# 1/1 [==============================] - 0s 82ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 71ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 112ms/step
# CPU times: user 43.5 s, sys: 797 ms, total: 44.3 s
# Wall time: 41 s

# %%
VideoFileClip("Human-Activity-Prediction.avi", audio=False).ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
